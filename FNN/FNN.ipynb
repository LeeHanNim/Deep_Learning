# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# WARNING:tensorflow:From <ipython-input-1-76cba88990fd>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y_i, f(x_i; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        loss=-tf.reduce_mean(tf.reduce_sum(y_true*tf.log(y_hat),axis=1))
        #loss=y_true*tf.log(y_hat) #shape=(?,10)
        #loss=tf.reduce_mean(y_true*tf.log(y_hat),axis=0) #shape=(10,)
    return loss

y_true=tf.placeholder(tf.float32,[None,10])
y_hat=tf.placeholder(tf.float32,[None,10])
get_cross_entropy_loss(y_true,y_hat)

#값이 하나여서 shape은 안보임
# Out:
# <tf.Tensor 'cross_entropy/Neg:0' shape=() dtype=float32>

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.01
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """
    with tf.variable_scope(name):
        shp=inputs.get_shape().as_list()[1]
         #밑에서 layer 2개를 쓸 때 fc 두번 부름 => variable 썼는데 왜 또 쓰냐 오류
        initial = tf.truncated_normal([shp,out_dim], stddev=0.01) #W=D*M 
        weights = tf.get_variable('w', initializer=initial)
        y_hat = tf.matmul(inputs, weights)
        return y_hat

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
###################################################################
#                    Implementation 3-1                           #
###################################################################
#train_data = None
#test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################
x = tf.placeholder(tf.float32,[None,784])
y_true = tf.placeholder(tf.float32,[None,10])

###################################################################
#                    Implementation 3-3                          #
###################################################################
h1 = fc('layer1',512,x)
y_logits=fc('layer2',10,h1) #layer 2개짜리를 만듬
y_hat = tf.nn.softmax(y_logits) #가지고 있는 확률을 다 합쳐서 1이 되도록 해줌

###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true,y_hat)

# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()

with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_x, y_true: batch_y})
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 0.9140, test accuracy: 0.7821
# 20th iteration, loss: 0.6360, test accuracy: 0.7702
# 30th iteration, loss: 0.7847, test accuracy: 0.8506
# 40th iteration, loss: 0.9220, test accuracy: 0.8627
# 50th iteration, loss: 0.2549, test accuracy: 0.8315
# 60th iteration, loss: 0.5126, test accuracy: 0.8642
# 70th iteration, loss: 0.4816, test accuracy: 0.8358
# 80th iteration, loss: 0.9102, test accuracy: 0.8488
# 90th iteration, loss: 0.2920, test accuracy: 0.8717
# 100th iteration, loss: 0.5071, test accuracy: 0.8657
# 110th iteration, loss: 0.6024, test accuracy: 0.8630
# 120th iteration, loss: 0.7766, test accuracy: 0.8535
# 130th iteration, loss: 0.5808, test accuracy: 0.8805
# 140th iteration, loss: 0.4976, test accuracy: 0.8560
# 150th iteration, loss: 0.5231, test accuracy: 0.8765
# 160th iteration, loss: 0.4867, test accuracy: 0.8788
# 170th iteration, loss: 0.3907, test accuracy: 0.8544
# 180th iteration, loss: 0.9015, test accuracy: 0.8531
# 190th iteration, loss: 0.6057, test accuracy: 0.8738
# 200th iteration, loss: 0.6898, test accuracy: 0.8575
# 210th iteration, loss: 0.8542, test accuracy: 0.8532
# 220th iteration, loss: 0.6437, test accuracy: 0.8934
# 230th iteration, loss: 0.8554, test accuracy: 0.8547
# 240th iteration, loss: 0.5879, test accuracy: 0.8430
# 250th iteration, loss: 0.4514, test accuracy: 0.8634
# 260th iteration, loss: 0.8277, test accuracy: 0.8779
# 270th iteration, loss: 0.5129, test accuracy: 0.8695
# 280th iteration, loss: 0.3861, test accuracy: 0.8562
# 290th iteration, loss: 0.7920, test accuracy: 0.8786
# 300th iteration, loss: 0.4820, test accuracy: 0.8293
# 310th iteration, loss: 0.6751, test accuracy: 0.8789
# 320th iteration, loss: 0.4424, test accuracy: 0.8831
# 330th iteration, loss: 0.3711, test accuracy: 0.8837
# 340th iteration, loss: 0.4415, test accuracy: 0.8927
# 350th iteration, loss: 0.5190, test accuracy: 0.8625
# 360th iteration, loss: 0.5764, test accuracy: 0.8791
# 370th iteration, loss: 0.2239, test accuracy: 0.8872
# 380th iteration, loss: 0.6480, test accuracy: 0.8454
# 390th iteration, loss: 0.4439, test accuracy: 0.8598
# 400th iteration, loss: 0.2312, test accuracy: 0.8788
# 410th iteration, loss: 0.5712, test accuracy: 0.8681
# 420th iteration, loss: 0.7247, test accuracy: 0.8651
# 430th iteration, loss: 0.3738, test accuracy: 0.8802
# 440th iteration, loss: 0.4143, test accuracy: 0.8554
# 450th iteration, loss: 1.0425, test accuracy: 0.8823
# 460th iteration, loss: 0.6463, test accuracy: 0.8658
# 470th iteration, loss: 0.7788, test accuracy: 0.8775
# 480th iteration, loss: 0.8917, test accuracy: 0.8622
# 490th iteration, loss: 0.5338, test accuracy: 0.8659
# 500th iteration, loss: 0.7393, test accuracy: 0.8595
# 510th iteration, loss: 1.3735, test accuracy: 0.8660
# 520th iteration, loss: 0.3146, test accuracy: 0.8736
# 530th iteration, loss: 0.4009, test accuracy: 0.8894
# 540th iteration, loss: 0.4477, test accuracy: 0.8921
# 550th iteration, loss: 1.1056, test accuracy: 0.8612
# 560th iteration, loss: 0.4629, test accuracy: 0.8767
# 570th iteration, loss: 0.3744, test accuracy: 0.8781
# 580th iteration, loss: 0.4479, test accuracy: 0.8895
# 590th iteration, loss: 0.5222, test accuracy: 0.8778
# 600th iteration, loss: 0.3486, test accuracy: 0.8714
# 610th iteration, loss: 0.7620, test accuracy: 0.8851
# 620th iteration, loss: 0.7482, test accuracy: 0.8862
# 630th iteration, loss: 0.5021, test accuracy: 0.8699
# 640th iteration, loss: 0.1932, test accuracy: 0.8660
# 650th iteration, loss: 0.6816, test accuracy: 0.8865
# 660th iteration, loss: 0.3379, test accuracy: 0.8770
# 670th iteration, loss: 0.4082, test accuracy: 0.8737
# 680th iteration, loss: 0.4631, test accuracy: 0.8895
# 690th iteration, loss: 0.5069, test accuracy: 0.8821
# 700th iteration, loss: 0.5121, test accuracy: 0.8749
# 710th iteration, loss: 1.1628, test accuracy: 0.8825
# 720th iteration, loss: 0.2827, test accuracy: 0.8773
# 730th iteration, loss: 0.4136, test accuracy: 0.9001
# 740th iteration, loss: 0.4469, test accuracy: 0.8929
# 750th iteration, loss: 0.5710, test accuracy: 0.8647
# 760th iteration, loss: 0.5166, test accuracy: 0.8872
# 770th iteration, loss: 0.5515, test accuracy: 0.8812
# 780th iteration, loss: 0.6156, test accuracy: 0.8700
# 790th iteration, loss: 0.6964, test accuracy: 0.8708
# 800th iteration, loss: 0.2758, test accuracy: 0.8661
# 810th iteration, loss: 0.6929, test accuracy: 0.8775
# 820th iteration, loss: 0.6117, test accuracy: 0.8672
# 830th iteration, loss: 0.4792, test accuracy: 0.8677
# 840th iteration, loss: 0.5879, test accuracy: 0.8868
# 850th iteration, loss: 0.3342, test accuracy: 0.8597
# 860th iteration, loss: 0.5358, test accuracy: 0.8651
# 870th iteration, loss: 0.3677, test accuracy: 0.8860
# 880th iteration, loss: 0.4556, test accuracy: 0.8883
# 890th iteration, loss: 0.3426, test accuracy: 0.8941
# 900th iteration, loss: 0.6588, test accuracy: 0.8590
# 910th iteration, loss: 0.4752, test accuracy: 0.8914
# 920th iteration, loss: 0.4887, test accuracy: 0.8504
# 930th iteration, loss: 0.5825, test accuracy: 0.8868
# 940th iteration, loss: 0.3939, test accuracy: 0.8993
# 950th iteration, loss: 0.6130, test accuracy: 0.8991
# 960th iteration, loss: 0.2311, test accuracy: 0.8674
# 970th iteration, loss: nan, test accuracy: 0.0980
# 980th iteration, loss: nan, test accuracy: 0.0980
# 990th iteration, loss: nan, test accuracy: 0.0980
# 1000th iteration, loss: nan, test accuracy: 0.0980
# 1010th iteration, loss: nan, test accuracy: 0.0980
# 1020th iteration, loss: nan, test accuracy: 0.0980
# 1030th iteration, loss: nan, test accuracy: 0.0980
# 1040th iteration, loss: nan, test accuracy: 0.0980
# 1050th iteration, loss: nan, test accuracy: 0.0980
# 1060th iteration, loss: nan, test accuracy: 0.0980
# 1070th iteration, loss: nan, test accuracy: 0.0980
# 1080th iteration, loss: nan, test accuracy: 0.0980
# 1090th iteration, loss: nan, test accuracy: 0.0980
# 1100th iteration, loss: nan, test accuracy: 0.0980
# 1110th iteration, loss: nan, test accuracy: 0.0980
# 1120th iteration, loss: nan, test accuracy: 0.0980
# 1130th iteration, loss: nan, test accuracy: 0.0980
# 1140th iteration, loss: nan, test accuracy: 0.0980
# 1150th iteration, loss: nan, test accuracy: 0.0980
# 1160th iteration, loss: nan, test accuracy: 0.0980
# 1170th iteration, loss: nan, test accuracy: 0.0980
# 1180th iteration, loss: nan, test accuracy: 0.0980
# 1190th iteration, loss: nan, test accuracy: 0.0980
# 1200th iteration, loss: nan, test accuracy: 0.0980
# 1210th iteration, loss: nan, test accuracy: 0.0980
# 1220th iteration, loss: nan, test accuracy: 0.0980
# 1230th iteration, loss: nan, test accuracy: 0.0980
# 1240th iteration, loss: nan, test accuracy: 0.0980
# 1250th iteration, loss: nan, test accuracy: 0.0980
# 1260th iteration, loss: nan, test accuracy: 0.0980
# 1270th iteration, loss: nan, test accuracy: 0.0980
# 1280th iteration, loss: nan, test accuracy: 0.0980
# 1290th iteration, loss: nan, test accuracy: 0.0980
# 1300th iteration, loss: nan, test accuracy: 0.0980
# 1310th iteration, loss: nan, test accuracy: 0.0980
# 1320th iteration, loss: nan, test accuracy: 0.0980
# 1330th iteration, loss: nan, test accuracy: 0.0980
# 1340th iteration, loss: nan, test accuracy: 0.0980
# 1350th iteration, loss: nan, test accuracy: 0.0980
# 1360th iteration, loss: nan, test accuracy: 0.0980
# 1370th iteration, loss: nan, test accuracy: 0.0980
# 1380th iteration, loss: nan, test accuracy: 0.0980
# 1390th iteration, loss: nan, test accuracy: 0.0980
# 1400th iteration, loss: nan, test accuracy: 0.0980
# 1410th iteration, loss: nan, test accuracy: 0.0980
# 1420th iteration, loss: nan, test accuracy: 0.0980
# 1430th iteration, loss: nan, test accuracy: 0.0980
# 1440th iteration, loss: nan, test accuracy: 0.0980
# 1450th iteration, loss: nan, test accuracy: 0.0980
# 1460th iteration, loss: nan, test accuracy: 0.0980
# 1470th iteration, loss: nan, test accuracy: 0.0980
# 1480th iteration, loss: nan, test accuracy: 0.0980
# 1490th iteration, loss: nan, test accuracy: 0.0980
# 1500th iteration, loss: nan, test accuracy: 0.0980
# 1510th iteration, loss: nan, test accuracy: 0.0980
# 1520th iteration, loss: nan, test accuracy: 0.0980
# 1530th iteration, loss: nan, test accuracy: 0.0980
# 1540th iteration, loss: nan, test accuracy: 0.0980
# 1550th iteration, loss: nan, test accuracy: 0.0980
# 1560th iteration, loss: nan, test accuracy: 0.0980
# 1570th iteration, loss: nan, test accuracy: 0.0980
# 1580th iteration, loss: nan, test accuracy: 0.0980
# 1590th iteration, loss: nan, test accuracy: 0.0980
# 1600th iteration, loss: nan, test accuracy: 0.0980
# 1610th iteration, loss: nan, test accuracy: 0.0980
# 1620th iteration, loss: nan, test accuracy: 0.0980
# 1630th iteration, loss: nan, test accuracy: 0.0980
# 1640th iteration, loss: nan, test accuracy: 0.0980
# 1650th iteration, loss: nan, test accuracy: 0.0980
# 1660th iteration, loss: nan, test accuracy: 0.0980
# 1670th iteration, loss: nan, test accuracy: 0.0980
# 1680th iteration, loss: nan, test accuracy: 0.0980
# 1690th iteration, loss: nan, test accuracy: 0.0980
# 1700th iteration, loss: nan, test accuracy: 0.0980
# 1710th iteration, loss: nan, test accuracy: 0.0980
# 1720th iteration, loss: nan, test accuracy: 0.0980
# 1730th iteration, loss: nan, test accuracy: 0.0980
# 1740th iteration, loss: nan, test accuracy: 0.0980
# 1750th iteration, loss: nan, test accuracy: 0.0980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-31a563732912> in <module>
#      44         _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_x, y_true: batch_y})
#      45         # calcualte accuracy
# ---> 46         acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
#      47         # print loss (cross entropy) and accuracy at every 10th step
#      48         if (step + 1) % 10 == 0:
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
